# %%
import pathlib
project_path = pathlib.Path().resolve().parent.parent
paths = []

import sys
path = project_path.joinpath("benchmark/third_party/bench-mr/python").as_posix()
if path not in sys.path:
    sys.path.append(path)

import os
os.environ["MPB_BINARY"] = "./benchmark"
os.environ["MPB_PYTHON_BINARY"] = "../../../../scripts/run_gpmp2.py"
os.environ["MPB_BINARY_DIR"] = "/home/mikhail/research/pytorch-motion-planner/benchmark/third_party/bench-mr/bin"
os.environ["PYTHONPATH"] = "../../../../build/benchmark:" + project_path.as_posix()

scenario_path = project_path.joinpath("benchmark/third_party/bench-mr/bin/moving_ai_scenarios")


import matplotlib as mpl
mpl.rcParams['mathtext.fontset'] = 'cm'
# make sure to not use Level-3 fonts
mpl.rcParams['pdf.fonttype'] = 42

from plot_env import plot_env
import json
from plot_env import plot_env, plot_env_options
from plot_trajectory import plot_trajectory, plot_nodes, plot_trajectory_options
from color import get_color, get_colors
import matplotlib.pyplot as plt
from mpb import MPB, MultipleMPB
from plot_stats import plot_planner_stats

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# # Run one experiment

# %%
m = MPB()
m["benchmark.moving_ai.active"] = True
m["benchmark.moving_ai.create_border"] = False
i = -2
m["benchmark.moving_ai.start"] = i
m["benchmark.moving_ai.end"] = i + 1
m["benchmark.moving_ai.scenario"] = scenario_path.joinpath("Berlin_0_256.map.scen").as_posix() 

m["max_planning_time"] = 60
m["benchmark.planning"]['constrained_onf_planner'] = True
m["steer.car_turning_radius"] = 4
m["sbpl.scaling"] = 1
# m.set_planners(['constrained_onf_planner', 'bfmt', 'cforest', 'prm', 'prm_star', 'informed_rrt_star', 'sbpl_mha'])
# m.set_planners(['constrained_onf_planner', 'informed_rrt_star', 'sbpl_mha'])
m.set_planners(['constrained_onf_planner'])
m.run(id="movingai", runs=1)
# Out:
# Running MPB with ID movingai (log file at movingai.log)...
# movingai:   0%|          | 0/1 [00:00<?, ?it/s]
# 0

# %%
m.visualize_trajectories(draw_start_goal_thetas=True,
                         plot_every_nth_polygon=8,
                         fig_width=8,
                         fig_height=8,
                         silence=True,
                         save_file="plots/movingai_experiment.pdf",
                         num_colors=10)

# %%
env = os.environ
env["MPLBACKEND"] = "TkAgg"
pool = MultipleMPB()
for i in range(50):
    m = MPB()
    m["benchmark.moving_ai.active"] = True
    m["benchmark.moving_ai.create_border"] = False
    m["benchmark.moving_ai.start"] = -i - 1
    m["benchmark.moving_ai.end"] = -i
    m["benchmark.moving_ai.scenario"] = scenario_path.joinpath("Berlin_0_256.map.scen").as_posix()  

    m["max_planning_time"] = 60
    m["benchmark.planning"]['constrained_onf_planner'] = True
    m["steer.car_turning_radius"] = 2
    m["sbpl.scaling"] = 1
    m.set_planners(['constrained_onf_planner'])
    pool.benchmarks.append(m)

pool.run_parallel(id="movingai_pool", runs=1, processes=1)
# Out:
# Available memory: 15.59 GB, limiting each MPB process to 41.7% usage (6.50 GB).
# Creating pool of 1 processes.
# Running MPB with ID movingai_pool_0 (log file at movingai_pool/movingai_pool_0.log)...
# movingai_pool_0:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 0 (movingai_pool_0) finished successfully.
# Running MPB with ID movingai_pool_1 (log file at movingai_pool/movingai_pool_1.log)...
# movingai_pool_1:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 1 (movingai_pool_1) finished successfully.
# Running MPB with ID movingai_pool_2 (log file at movingai_pool/movingai_pool_2.log)...
# movingai_pool_2:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 2 (movingai_pool_2) finished successfully.
# Running MPB with ID movingai_pool_3 (log file at movingai_pool/movingai_pool_3.log)...
# movingai_pool_3:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 3 (movingai_pool_3) finished successfully.
# Running MPB with ID movingai_pool_4 (log file at movingai_pool/movingai_pool_4.log)...
# movingai_pool_4:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 4 (movingai_pool_4) finished successfully.
# Running MPB with ID movingai_pool_5 (log file at movingai_pool/movingai_pool_5.log)...
# movingai_pool_5:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 5 (movingai_pool_5) finished successfully.
# Running MPB with ID movingai_pool_6 (log file at movingai_pool/movingai_pool_6.log)...
# movingai_pool_6:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 6 (movingai_pool_6) finished successfully.
# Running MPB with ID movingai_pool_7 (log file at movingai_pool/movingai_pool_7.log)...
# movingai_pool_7:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 7 (movingai_pool_7) finished successfully.
# Running MPB with ID movingai_pool_8 (log file at movingai_pool/movingai_pool_8.log)...
# movingai_pool_8:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 8 (movingai_pool_8) finished successfully.
# Running MPB with ID movingai_pool_9 (log file at movingai_pool/movingai_pool_9.log)...
# movingai_pool_9:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 9 (movingai_pool_9) finished successfully.
# Running MPB with ID movingai_pool_10 (log file at movingai_pool/movingai_pool_10.log)...
# movingai_pool_10:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 10 (movingai_pool_10) finished successfully.
# Running MPB with ID movingai_pool_11 (log file at movingai_pool/movingai_pool_11.log)...
# movingai_pool_11:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 11 (movingai_pool_11) finished successfully.
# Running MPB with ID movingai_pool_12 (log file at movingai_pool/movingai_pool_12.log)...
# movingai_pool_12:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 12 (movingai_pool_12) finished successfully.
# Running MPB with ID movingai_pool_13 (log file at movingai_pool/movingai_pool_13.log)...
# movingai_pool_13:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 13 (movingai_pool_13) finished successfully.
# Running MPB with ID movingai_pool_14 (log file at movingai_pool/movingai_pool_14.log)...
# movingai_pool_14:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 14 (movingai_pool_14) finished successfully.
# Running MPB with ID movingai_pool_15 (log file at movingai_pool/movingai_pool_15.log)...
# movingai_pool_15:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 15 (movingai_pool_15) finished successfully.
# Running MPB with ID movingai_pool_16 (log file at movingai_pool/movingai_pool_16.log)...
# movingai_pool_16:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 16 (movingai_pool_16) finished successfully.
# Running MPB with ID movingai_pool_17 (log file at movingai_pool/movingai_pool_17.log)...
# movingai_pool_17:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 17 (movingai_pool_17) finished successfully.
# Running MPB with ID movingai_pool_18 (log file at movingai_pool/movingai_pool_18.log)...
# movingai_pool_18:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 18 (movingai_pool_18) finished successfully.
# Running MPB with ID movingai_pool_19 (log file at movingai_pool/movingai_pool_19.log)...
# movingai_pool_19:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 19 (movingai_pool_19) finished successfully.
# Running MPB with ID movingai_pool_20 (log file at movingai_pool/movingai_pool_20.log)...
# movingai_pool_20:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 20 (movingai_pool_20) finished successfully.
# Running MPB with ID movingai_pool_21 (log file at movingai_pool/movingai_pool_21.log)...
# movingai_pool_21:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 21 (movingai_pool_21) finished successfully.
# Running MPB with ID movingai_pool_22 (log file at movingai_pool/movingai_pool_22.log)...
# movingai_pool_22:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 22 (movingai_pool_22) finished successfully.
# Running MPB with ID movingai_pool_23 (log file at movingai_pool/movingai_pool_23.log)...
# movingai_pool_23:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 23 (movingai_pool_23) finished successfully.
# Running MPB with ID movingai_pool_24 (log file at movingai_pool/movingai_pool_24.log)...
# movingai_pool_24:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 24 (movingai_pool_24) finished successfully.
# Running MPB with ID movingai_pool_25 (log file at movingai_pool/movingai_pool_25.log)...
# movingai_pool_25:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 25 (movingai_pool_25) finished successfully.
# Running MPB with ID movingai_pool_26 (log file at movingai_pool/movingai_pool_26.log)...
# movingai_pool_26:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 26 (movingai_pool_26) finished successfully.
# Running MPB with ID movingai_pool_27 (log file at movingai_pool/movingai_pool_27.log)...
# movingai_pool_27:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 27 (movingai_pool_27) finished successfully.
# Running MPB with ID movingai_pool_28 (log file at movingai_pool/movingai_pool_28.log)...
# movingai_pool_28:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 28 (movingai_pool_28) finished successfully.
# Running MPB with ID movingai_pool_29 (log file at movingai_pool/movingai_pool_29.log)...
# movingai_pool_29:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 29 (movingai_pool_29) finished successfully.
# Running MPB with ID movingai_pool_30 (log file at movingai_pool/movingai_pool_30.log)...
# movingai_pool_30:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 30 (movingai_pool_30) finished successfully.
# Running MPB with ID movingai_pool_31 (log file at movingai_pool/movingai_pool_31.log)...
# movingai_pool_31:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 31 (movingai_pool_31) finished successfully.
# Running MPB with ID movingai_pool_32 (log file at movingai_pool/movingai_pool_32.log)...
# movingai_pool_32:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 32 (movingai_pool_32) finished successfully.
# Running MPB with ID movingai_pool_33 (log file at movingai_pool/movingai_pool_33.log)...
# movingai_pool_33:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 33 (movingai_pool_33) finished successfully.
# Running MPB with ID movingai_pool_34 (log file at movingai_pool/movingai_pool_34.log)...
# movingai_pool_34:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 34 (movingai_pool_34) finished successfully.
# Running MPB with ID movingai_pool_35 (log file at movingai_pool/movingai_pool_35.log)...
# movingai_pool_35:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 35 (movingai_pool_35) finished successfully.
# Running MPB with ID movingai_pool_36 (log file at movingai_pool/movingai_pool_36.log)...
# movingai_pool_36:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 36 (movingai_pool_36) finished successfully.
# Running MPB with ID movingai_pool_37 (log file at movingai_pool/movingai_pool_37.log)...
# movingai_pool_37:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 37 (movingai_pool_37) finished successfully.
# Running MPB with ID movingai_pool_38 (log file at movingai_pool/movingai_pool_38.log)...
# movingai_pool_38:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 38 (movingai_pool_38) finished successfully.
# Running MPB with ID movingai_pool_39 (log file at movingai_pool/movingai_pool_39.log)...
# movingai_pool_39:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 39 (movingai_pool_39) finished successfully.
# Running MPB with ID movingai_pool_40 (log file at movingai_pool/movingai_pool_40.log)...
# movingai_pool_40:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 40 (movingai_pool_40) finished successfully.
# Running MPB with ID movingai_pool_41 (log file at movingai_pool/movingai_pool_41.log)...
# movingai_pool_41:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 41 (movingai_pool_41) finished successfully.
# Running MPB with ID movingai_pool_42 (log file at movingai_pool/movingai_pool_42.log)...
# movingai_pool_42:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 42 (movingai_pool_42) finished successfully.
# Running MPB with ID movingai_pool_43 (log file at movingai_pool/movingai_pool_43.log)...
# movingai_pool_43:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 43 (movingai_pool_43) finished successfully.
# Running MPB with ID movingai_pool_44 (log file at movingai_pool/movingai_pool_44.log)...
# movingai_pool_44:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 44 (movingai_pool_44) finished successfully.
# Running MPB with ID movingai_pool_45 (log file at movingai_pool/movingai_pool_45.log)...
# movingai_pool_45:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 45 (movingai_pool_45) finished successfully.
# Running MPB with ID movingai_pool_46 (log file at movingai_pool/movingai_pool_46.log)...
# movingai_pool_46:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 46 (movingai_pool_46) finished successfully.
# Running MPB with ID movingai_pool_47 (log file at movingai_pool/movingai_pool_47.log)...
# movingai_pool_47:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 47 (movingai_pool_47) finished successfully.
# Running MPB with ID movingai_pool_48 (log file at movingai_pool/movingai_pool_48.log)...
# movingai_pool_48:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 48 (movingai_pool_48) finished successfully.
# Running MPB with ID movingai_pool_49 (log file at movingai_pool/movingai_pool_49.log)...
# movingai_pool_49:   0%|          | 0/1 [00:00<?, ?it/s]
# Benchmark 49 (movingai_pool_49) finished successfully.
# All benchmarks succeeded.
# True

# %%
# pool.visualize_trajectories(draw_start_goal_thetas=True,
#                          plot_every_nth_polygon=8,
#                          fig_width=8,
#                          fig_height=8,
#                          silence=True,
#                          save_file="plots/movingai_experiment_pool.pdf",
#                          num_colors=10)

# %%
result = "movingai_results_gpmp2.json"
pool.merge(result, make_separate_runs=True)
plot_planner_stats(result, metrics="planning_time, cusps, path_length, max_curvature, smoothness, normalized_curvature, aggregate")
# Out:
# Successfully merged [movingai_pool/movingai_pool_0_results.json, movingai_pool/movingai_pool_1_results.json, movingai_pool/movingai_pool_2_results.json, movingai_pool/movingai_pool_3_results.json, movingai_pool/movingai_pool_4_results.json, movingai_pool/movingai_pool_5_results.json, movingai_pool/movingai_pool_6_results.json, movingai_pool/movingai_pool_7_results.json, movingai_pool/movingai_pool_8_results.json, movingai_pool/movingai_pool_9_results.json, movingai_pool/movingai_pool_10_results.json, movingai_pool/movingai_pool_11_results.json, movingai_pool/movingai_pool_12_results.json, movingai_pool/movingai_pool_13_results.json, movingai_pool/movingai_pool_14_results.json, movingai_pool/movingai_pool_15_results.json, movingai_pool/movingai_pool_16_results.json, movingai_pool/movingai_pool_17_results.json, movingai_pool/movingai_pool_18_results.json, movingai_pool/movingai_pool_19_results.json, movingai_pool/movingai_pool_20_results.json, movingai_pool/movingai_pool_21_results.json, movingai_pool/movingai_pool_22_results.json, movingai_pool/movingai_pool_23_results.json, movingai_pool/movingai_pool_24_results.json, movingai_pool/movingai_pool_25_results.json, movingai_pool/movingai_pool_26_results.json, movingai_pool/movingai_pool_27_results.json, movingai_pool/movingai_pool_28_results.json, movingai_pool/movingai_pool_29_results.json, movingai_pool/movingai_pool_30_results.json, movingai_pool/movingai_pool_31_results.json, movingai_pool/movingai_pool_32_results.json, movingai_pool/movingai_pool_33_results.json, movingai_pool/movingai_pool_34_results.json, movingai_pool/movingai_pool_35_results.json, movingai_pool/movingai_pool_36_results.json, movingai_pool/movingai_pool_37_results.json, movingai_pool/movingai_pool_38_results.json, movingai_pool/movingai_pool_39_results.json, movingai_pool/movingai_pool_40_results.json, movingai_pool/movingai_pool_41_results.json, movingai_pool/movingai_pool_42_results.json, movingai_pool/movingai_pool_43_results.json, movingai_pool/movingai_pool_44_results.json, movingai_pool/movingai_pool_45_results.json, movingai_pool/movingai_pool_46_results.json, movingai_pool/movingai_pool_47_results.json, movingai_pool/movingai_pool_48_results.json, movingai_pool/movingai_pool_49_results.json] into movingai_results_gpmp2.json.
# Visualizing movingai_results_gpmp2.json...

# %%
data = json.load(open(result, "r"))
data["runs"][0]["plans"]['gpmp2']['stats']
# Out:
# {'aol': 0.026931936326476277,
#  'collision_time': 0.125624,
#  'collisions': [[145.79240436224757, 121.36351914787676],
#   [145.55441594591696, 122.50967727678463],
#   [145.31642752958635, 123.6558354056925],
#   [145.07843911325574, 124.80199353460036],
#   [144.84045069692513, 125.94815166350823],
#   [144.60246228059452, 127.09430979241608],
#   [151.0018096448898, 249.25605988109888],
#   [152.19371977686177, 249.42842393677012],
